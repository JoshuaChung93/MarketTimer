# %%
# !pip install python-telegram-bot
# Out:
# ...
#
# [notice] A new release of pip available: 22.1.2 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import telegram
API_KEY = '5569257444:AAGV21Ds4fkrxhXkrevkdvQ289vGVcajYTU'
bot = telegram.Bot(token=API_KEY)

# %%
updates = bot.getUpdates()
updates
# Out:
# []

# %%
for i in bot.getUpdates():
    print(i.message)
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# File ~\miniconda3\envs\py38\lib\site-packages\telegram\vendor\ptb_urllib3\urllib3\connectionpool.py:402, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     399         except Exception as e:
#     400             # Remove the TypeError from the exception chain in Python 3;
#     401             # otherwise it looks like a programming error was the cause.
# --> 402             six.raise_from(e, None)
#     403 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:2, in raise_from(value, from_value)
#
# File ~\miniconda3\envs\py38\lib\site-packages\telegram\vendor\ptb_urllib3\urllib3\connectionpool.py:398, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     397 try:
# ...

# %%
bot.sendMessage(chat_id='1760120639', text='hello world')

# %%
# 필요한 라이브러리 설치 및 불러오기
# !pip install -U finance-datareader
import FinanceDataReader as fdr
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
import datetime
import sys
fdr.__version__
# Out:
# ...
#
# [notice] A new release of pip available: 22.1.2 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# '0.9.34'

# %%
plt.style.use(['default']) # 다크모드에서 보기
plt.title('KOSDAQ')
df = fdr.DataReader('KQ11', '2022')
df['Close'].plot(figsize=(12,6), label='KOSDAQ_CLOSE')
plt.legend()
plt.show()

# %%
# 3,5,10 단순이동평균
plt.title('KOSDAQ')
df['Close'].plot(figsize=(12,6), label='KOSDAQ_CLOSE')
df['Close'].rolling(3).mean().plot(label = '3 Days MA')
df['Close'].rolling(5).mean().plot(label = '5 Days MA')
df['Close'].rolling(10).mean().plot(label = '10 Days MA')
plt.legend()
plt.show()

# %%
# 3,5,10 이동평균 딕셔너리에 할당
df['close_sma3d'] = df['Close'].rolling(3).mean()
df['close_sma5d'] = df['Close'].rolling(5).mean()
df['close_sma10d'] = df['Close'].rolling(10).mean()

# %%
df.iloc[-20:]
# Out:
#              Close    Open    High     Low        Volume  Change  close_sma3d  \
# Date
# 2022-07-29  803.62  802.97  807.77  801.05  7.844000e+08  0.0066   799.213333
# 2022-08-01  807.61  804.15  808.96  801.40  8.230600e+08  0.0050   803.183333
# 2022-08-02  804.34  807.69  807.69  799.36  9.059400e+08 -0.0040   805.190000
# 2022-08-03  815.36  804.17  815.40  803.20  9.972700e+08  0.0137   809.103333
# 2022-08-04  825.16  820.06  825.99  820.06  9.084900e+08  0.0120   814.953333
# 2022-08-05  831.64  826.23  832.27  826.23  9.317600e+08  0.0079   824.053333
# 2022-08-08  830.86  829.77  831.12  825.94  9.314500e+08 -0.0009   829.220000
# 2022-08-09  833.65  831.13  833.94  826.45  9.766900e+08  0.0034   832.050000
# 2022-08-10  820.27  829.29  829.29  820.27  8.972200e+08 -0.0160   828.260000
# 2022-08-11  832.15  831.99  834.88  828.27  8.978300e+08  0.0145   828.690000
# 2022-08-12  831.63  831.18  833.70  826.72  7.924300e+08 -0.0006   828.016667
# ...

# %%
# 최근 10일 데이터만 불러오기
df.loc[: ,['Close', 'close_sma3d','close_sma5d','close_sma10d']].iloc[-10:]
# Out:
#              Close  close_sma3d  close_sma5d  close_sma10d
# Date
# 2022-08-12  831.63   828.016667      829.712       823.267
# 2022-08-16  834.74   832.840000      830.488       825.980
# 2022-08-17  827.42   831.263333      829.242       828.288
# 2022-08-18  826.06   829.406667      830.400       829.358
# 2022-08-19  814.17   822.550000      826.804       828.259
# 2022-08-22  795.87   812.033333      819.652       824.682
# 2022-08-23  783.42   797.820000      809.388       819.938
# 2022-08-24  793.14   790.810000      802.532       815.887
# 2022-08-25  807.37   794.643333      798.794       814.597
# 2022-08-26  802.45   800.986667      796.450       811.627

# %%
# series to dataframe
print(type(df))
df.to_frame(name="KOSDAQ")
print(df)
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [13], in <cell line: 3>()
#       1 # series to dataframe
#       2 print(type(df))
# ----> 3 df.to_frame(name="KOSDAQ")
#       4 print(df)
#       5 print(type(df))
#
# File ~\miniconda3\envs\py38\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'to_frame'

# %%
# for문 사용하여 읽기
d = {}

for data_name in ['Close','close_sma3d','close_sma5d','close_sma10d']:
    print(f'read csv {data_name}...')
    d[data_name] = pd.read_csv(f"KOSDAQ.{data_name}.csv", index_col=0, encoding='utf-8-sig', parse_dates=True)
    print(f"done! {d[data_name].shape}")
